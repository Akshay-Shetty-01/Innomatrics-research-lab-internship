# %% [markdown]
# <a href="https://colab.research.google.com/github/pavanikasul/Pavani_Task_and_Assesment_IN226125602_Innomatics/blob/main/Task_7_Python_problem_solving_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1.Smart Light Controller**

# %%
class Smart_light:
  def __init__(self,name):
    self.name=name
    self.status=False
  def light_on(self):
    self.status=True
  def light_off(self):
    self.status=False

  def display_status(self):
    if self.status:
      print(f"{self.name} is ON")

    else:
      print(f"{self.name} is OFF")

light=Smart_light("Bedroom Light")
light.light_on()
light.display_status()
# Out:
# Bedroom Light is ON

# %% [markdown]
# **2.Employee ID Card System**

# %%
class Employee:
  def __init__(self,name,id,department):
    self.name=name
    self.id=id
    self.department=department

  def details(self):
    print("Employee ID Card Details:")
    print(f"Employee Name:{self.name}")
    print(f"Employee ID:{self.id}")
    print(f"Employee Department:{self.department}")

detail=Employee("Rahul","EMP102","IT")
detail.details()
# Out:
# Employee ID Card Details:
# Employee Name:Rahul
# Employee ID:EMP102
# Employee Department:IT

# %% [markdown]
# **3.Mobile Contact Record**

# %%
class Contact:
  def __init__(self,name,phone_no):
    self.name=name
    self.phone_no=phone_no

  def display_status(self):
    print("Contact Saved")
    print(f"Name:{self.name}")
    print(f"Phone:{self.phone_no}")

contacts=Contact("Anita","9876543210")
contacts.display_status()
# Out:
# Contact Saved
# Name:Anita
# Phone:9876543210

# %% [markdown]
# **4.Product Price Tag Generator**

# %%
class Store:
  def __init__(self,name,price):
    self.name=name
    self.price=price

  def display_amount(self):
    print(f"Product Name:{self.name}")
    print(f"Price:₹{self.price}")
stores=Store("Headphones","2499")
stores.display_amount()
# Out:
# Product Name:Headphones
# Price:₹2499

# %% [markdown]
# **5.Movie Rating Display System**

# %%
class Movie_rating:
  def __init__(self,name,rating):
    self.name=name
    self.rating=rating

  def display_movie_details(self):
    print(f"Movie Name: {self.name}")
    print(f"Movie Rating: {self.rating}")
movie_detail=Movie_rating("Inception", "4.8/5")
movie_detail.display_movie_details()
# Out:
# Movie Name: Inception
# Movie Rating: 4.8/5

# %% [markdown]
# **6.Delivery Address Manager**

# %%
class Delivery_details:
  def __init__(self,name, address):
    self.name=name
    self.address=address

  def display_delivery_details(self):
    print(f"Delivery Details")
    print(f"Customer Name: {self.name}")
    print(f"Address: {self.address}")

delivery_detail=Delivery_details("Suman", "Hyderabad")
delivery_detail.display_delivery_details()
# Out:
# Delivery Details
# Customer Name: Suman
# Address: Hyderabad
