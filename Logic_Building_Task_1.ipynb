# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshay-Shetty-01/Innomatrics-research-lab-internship/blob/main/Logic_Building_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1. User Login Check

# %%
stored_username = "admin"
stored_password = "1234"

username = "admin"
password = "1234"

if username == stored_username and password == stored_password:
    print("Login Successful")
else:
    print("Invalid Credentials")

# %%
2. Pass / Fail Analyzer

# %%
marks = [45, 78, 90, 33, 60]

pass_count = 0
fail_count = 0

for mark in marks:
    if mark >= 50:
        pass_count += 1
    else:
        fail_count += 1

print("Total Students:", len(marks))
print("Passed Students:", pass_count)
print("Failed Students:", fail_count)

# %%
3. Simple Data Cleaner

# %%
names = [" Alice ", "bob", " CHARLIE "]


cleaned_names = [name.strip().lower() for name in names]


print(cleaned_names)

# %%
4. Message Length Analyzer

# %%
messages = ["Hi", "Welcome to the platform", "OK"]
for message in messages:
    length = len(message)
    print(f"Message: '{message}'")
    print(f"Length: {length}")

    if length > 10:
        print("Status: Longer than 10 characters ⚠️")
    else:
        print("Status: Within limit ✅")

    print("-" * 30)

# %%
5. Error Message Detector

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

error_count = logs.count("ERROR")

print("Total ERROR entries:", error_count)
